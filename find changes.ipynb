# %%
#Reference: http://ecocam.evsc.virginia.edu/change_detection_description/change_detection_description.htm

# %% [markdown]
# import cv2
# import matplotlib.pyplot as plt
# import copy

# %% [raw]
# #read images and calculte difference

# %% [raw]
# pre=cv2.imread("pre.jpg")
# post=cv2.imread("post.jpg")
# image= cv2.absdiff(pre, post)

# %% [raw]
# #Threshod difference image

# %%
change_gray=cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
plt.imshow(change_gray)
print(change_gray)
ret,thresh1 = cv2.threshold(change_gray,60,255,cv2.THRESH_BINARY)
# Out:
# [[51  4  5 ... 68 82 69]
#  [87 30 18 ... 47 47 31]
#  [57 36 48 ... 45 32 15]
#  ...
#  [72 74 75 ...  7  7  9]
#  [56 47 42 ... 10 10  6]
#  [40 26 12 ... 41 43 40]]

# %% [raw]
# # Show changed portion on pre image

# %%
H,W,C=image.shape
Result=copy.copy(pre)
for a in range(H-2):
    for b in range(W-2):
        if thresh1[a,b]==255:
            Result[a,b]=[0,0,255]
cv2.imwrite("Result.jpg",Result)
# Out:
# True

# %%
plt.imshow(Result)
